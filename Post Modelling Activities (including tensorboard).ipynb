# %% [markdown]
# # Data preparation and Visualization

# %%
from keras.datasets import fashion_mnist
# Out:
# C:\Users\raghu\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.25.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
(x_train,y_train),(x_test,y_test)=fashion_mnist.load_data()

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
import matplotlib.pyplot as plt

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
plt.figure(figsize=(10, 10))
for i in range(16):
    plt.subplot(4, 4, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i], cmap='gray')
    plt.xlabel(class_names[y_train[i]])
plt.show()

# %%
# Normalizing
x_train,x_test=x_train/255.0,x_test/255.0

# %%
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %% [markdown]
# # Model Building and Training

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense

model = Sequential([
    Flatten(input_shape=(28, 28)), 
    Dense(128, activation='relu'),
    Dense(256, activation='relu'),
    Dense(10, activation='softmax')  # Output layer with 10 classes
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# C:\Users\raghu\anaconda3\lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
from tensorflow.keras.callbacks import TensorBoard
import datetime

# Set up TensorBoard callback
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)

# %%
history = model.fit(x_train, y_train, epochs=10, batch_size=64,
                    validation_split=0.2, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.7580 - loss: 0.6967 - val_accuracy: 0.8450 - val_loss: 0.4210
# Epoch 2/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.8623 - loss: 0.3807 - val_accuracy: 0.8622 - val_loss: 0.3815
# Epoch 3/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8757 - loss: 0.3417 - val_accuracy: 0.8748 - val_loss: 0.3481
# Epoch 4/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.8840 - loss: 0.3145 - val_accuracy: 0.8754 - val_loss: 0.3417
# Epoch 5/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.8936 - loss: 0.2916 - val_accuracy: 0.8808 - val_loss: 0.3346
# Epoch 6/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.8956 - loss: 0.2775 - val_accuracy: 0.8765 - val_loss: 0.3382
# Epoch 7/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9013 - loss: 0.2622 - val_accuracy: 0.8830 - val_loss: 0.3290
# Epoch 8/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9098 - loss: 0.2443 - val_accuracy: 0.8881 - val_loss: 0.3182
# Epoch 9/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9092 - loss: 0.2383 - val_accuracy: 0.8859 - val_loss: 0.3245
# Epoch 10/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9125 - loss: 0.2311 - val_accuracy: 0.8881 - val_loss: 0.3293

# %% [markdown]
# # Model Evaluation and Analysis

# %%
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f'Test accuracy: {test_accuracy}')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8835 - loss: 0.3494
# Test accuracy: 0.8828999996185303

# %%
! pip install tensorboard
# Out:
# Requirement already satisfied: tensorboard in c:\users\raghu\anaconda3\lib\site-packages (2.16.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\raghu\anaconda3\lib\site-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\raghu\anaconda3\lib\site-packages (from tensorboard) (1.25.0)
# Requirement already satisfied: six>1.9 in c:\users\raghu\anaconda3\lib\site-packages (from tensorboard) (1.16.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\raghu\anaconda3\lib\site-packages (from tensorboard) (63.4.1)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in c:\users\raghu\anaconda3\lib\site-packages (from tensorboard) (4.25.3)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\raghu\anaconda3\lib\site-packages (from tensorboard) (3.3.4)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\raghu\anaconda3\lib\site-packages (from tensorboard) (1.51.3)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\raghu\anaconda3\lib\site-packages (from tensorboard) (2.3.6)
# Requirement already satisfied: absl-py>=0.4 in c:\users\raghu\anaconda3\lib\site-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\raghu\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard) (2.1.3)
# WARNING: Ignoring invalid distribution -orch (c:\users\raghu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\raghu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\raghu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\raghu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\raghu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\raghu\anaconda3\lib\site-packages)

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs/fit
# Out:
#       <iframe id="tensorboard-frame-c6ae1b376b611c9c" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-c6ae1b376b611c9c");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
model.save('fashion_mnist_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# # MOdel Loading and verification

# %%
from tensorflow.keras.models import load_model

loaded_model = load_model('fashion_mnist_model.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
loaded_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)                    │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │         100,480 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 256)                 │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 10)                  │           2,570 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 136,076 (531.55 KB)
#  Trainable params: 136,074 (531.54 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)

# %%
# Compare the number of parameters
original_params = model.count_params()
loaded_params = loaded_model.count_params()

print(f'Original Model Parameters: {original_params}')
print(f'Loaded Model Parameters: {loaded_params}')
# Out:
# Original Model Parameters: 136074
# Loaded Model Parameters: 136074
